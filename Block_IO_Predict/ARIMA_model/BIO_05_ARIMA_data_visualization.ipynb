# %%
'''
작성일 : 2020-09-10
작성자 : 정성모
코드 개요 :
    Arima로 예측한 데이터와 실제 데이터 시각화
'''

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

nv_get = pd.read_csv("C:/Users/jsm97/Desktop/nv_get.csv")
nv_get = nv_get['0']
nv_get = nv_get[0:50000]
#print(nv_get[nv_get==0])

visual = pd.read_csv("C:/Users/jsm97/Desktop/ARIMA_diff_evaluation_10.csv")
mv=visual['missing value']
ori=visual['original']
print(mv[mv < 0])
#print(visual)
plt.figure(figsize=(15,15))
plt.subplot(2,1,1)
plt.title("Original & Forecast")
plt.xlabel("missing value count")
plt.ylabel("value")
plt.plot(mv,color='r')
plt.plot(ori)
plt.subplot(2,1,2)
plt.title("0 ~ 50000 Original Data")
plt.xlabel("index")
plt.ylabel("value")
plt.plot(nv_get)
# Out:
# 161   -1.010000e-05
# 162   -6.210000e-07
# 186   -2.390000e-05
# 312   -3.780000e-07
# 475   -2.460000e-06
# Name: missing value, dtype: float64
